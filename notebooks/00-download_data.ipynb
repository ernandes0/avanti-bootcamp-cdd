# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/atlantico-academy/datasets/main/diamonds.csv")
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
df.to_csv("../data/raw/data.csv", index=False)

# %%
dicionario = pd.DataFrame([
    {
        "variavel" : "carat",
        "descricao" : "Peso do diamante (0.2--5.01)",
        "tipo" : "quantitativa",
        "subtipo" : "contínua"
    },
    {
        "variavel" : "cut",
        "descricao" : "Qualidade do corte (Fair, Good, Very Good, Premium, Ideal)",
        "tipo" : "qualitativa",
        "subtipo" : "ordinal"
    },
    {
        "variavel" : "color",
        "descricao" : "Cor do diamante, de D (melhor) a J (pior)",
        "tipo" : "qualitativa",
        "subtipo" : "ordinal"
    },
    {
        "variavel" : "clarity",
        "descricao" : "Medida de quão claro é o diamante (I1 (pior), SI2, SI1, VS2, VS1, VVS2, VVS1, IF (melhor))",
        "tipo" : "qualitativa",
        "subtipo" : "ordinal"
    },
    {
        "variavel" : "depth",
        "descricao" : "Percentual de profundidade total = z / média(x, y) = 2 * z / (x + y) (43--79)",
        "tipo" : "quantitativa",
        "subtipo" : "contínua"
    },
    {
        "variavel" : "table",
        "descricao" : "Largura do topo do diamante em relação ao ponto mais largo (43--95)",
        "tipo" : "quantitativa",
        "subtipo" : "contínua"
    },
    {
        "variavel" : "price",
        "descricao" : "Preço em dólares americanos (US$326--US$18,823)",
        "tipo" : "quantitativa",
        "subtipo" : "contínua"
    },
    {
        "variavel" : "x",
        "descricao" : "Comprimento em mm (0--10.74)",
        "tipo" : "quantitativa",
        "subtipo" : "contínua"
    },
    {
        "variavel" : "y",
        "descricao" : "Largura em mm (0--58.9)",
        "tipo" : "quantitativa",
        "subtipo" : "contínua"
    },
    {
        "variavel" : "z",
        "descricao" : "Profundidade em mm (0--31.8)",
        "tipo" : "quantitativa",
        "subtipo" : "contínua"
    }
])
dicionario
# Out:
#   variavel                                          descricao          tipo  \
# 0    carat                       Peso do diamante (0.2--5.01)  quantitativa
# 1      cut  Qualidade do corte (Fair, Good, Very Good, Pre...   qualitativa
# 2    color          Cor do diamante, de D (melhor) a J (pior)   qualitativa
# 3  clarity  Medida de quão claro é o diamante (I1 (pior), ...   qualitativa
# 4    depth  Percentual de profundidade total = z / média(x...  quantitativa
# 5    table  Largura do topo do diamante em relação ao pont...  quantitativa
# 6    price    Preço em dólares americanos (US$326--US$18,823)  quantitativa
# 7        x                       Comprimento em mm (0--10.74)  quantitativa
# 8        y                            Largura em mm (0--58.9)  quantitativa
# 9        z                       Profundidade em mm (0--31.8)  quantitativa
#
#     subtipo
# 0  contínua
# 1   ordinal
# 2   ordinal
# 3   ordinal
# 4  contínua
# 5  contínua
# 6  contínua
# 7  contínua
# ...

# %%
dicionario.to_csv("../data/external/dictionary.csv", index=False)
